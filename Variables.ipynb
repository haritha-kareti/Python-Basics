# %% [markdown]
# # Variables

# %%
## Rules to Define Variables
# 1) Variable name will not start with a number
# 2) No white spaces in variable names, use ‘_’ instead
# 3) Variable names are case sensitive
# 4) Can’t use below symbols in variable names,
#      !@#$%^&*(){}<>:”’?/|\~-+

# %%
_& = 1
print(_&)
# Out:
#   File "/tmp/ipython-input-4216429004.py", line 1
#     _& = 1
#        ^
# SyntaxError: invalid syntax

# %%
& = 'kamal'
print(&)
# Out:
#   File "/tmp/ipython-input-4015303460.py", line 1
#     & = 'kamal'
#     ^
# SyntaxError: invalid syntax

# %%
13 = 'Data science '
print(13)
# Out:
#   File "/tmp/ipython-input-1838572888.py", line 1
#     13 = 'Data science '
#     ^
# SyntaxError: cannot assign to literal here. Maybe you meant '==' instead of '='?

# %%
a = 'python'
print(a)
# Out:
# python

# %%
_9lives='pythont'
print(_9lives)
# Out:
# pythont

# %%
a = 32.2
print(a)
# Out:
# 32.2

# %%
a = 'kamal'
print(a)
# Out:
# kamal

# %%
_123 = 'python'
print(_123)
# Out:
# python

# %%
course123 = 'datascience123'
print(course123)
# Out:
# datascience123

# %%
#Python variables can only begin with a letter(A-Z/a-z) or an underscore(_)
9lives = 9
# Out:
#   File "/tmp/ipython-input-4016610408.py", line 2
#     9lives = 9
#     ^
# SyntaxError: invalid decimal literal

# %%
a = 1
print(a)
type(a)
# Out:
# 1
# int

# %%
b = 1.2
print(b)
type(b)
# Out:
# 1.2
# float

# %%
c = 'python'
print(c)
type(c)
# Out:
# python
# str

# %%
a = 1
b = 12.2
c = 'python'
print(a , b,c)
print(type(a) , type(b) , type(c))
# Out:
# 1 12.2 python
# <class 'int'> <class 'float'> <class 'str'>

# %% [markdown]
# # concept of case sensitive

# %%
# case sensitive means Capital letters and small letters
# Python is a case sensitive language

# %%
a = 1
print(A)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2362963517.py in <cell line: 0>()
#       1 a = 1
# ----> 2 print(A)
#
# NameError: name 'A' is not defined

# %%
a = 12
b = 12
print(a)
print(b)
# Out:
# 12
# 12

# %%
a = 12 # a is not in a private manner
b = a
print(b)
# Out:
# 12

# %%
name='Ayushi'
name
# Out:
# 'Ayushi'

# %%
age=7
print(age)
# Out:
# 7

# %%
x = y = z = "Python"
print(x)
print(y)
print(z)
# Out:
# Python
# Python
# Python

# %%
a , b , c = 1 , 2 , 3
print(a , b , c)
# Out:
# 1 2 3

# %%
a , b , c = 'python', 1, 12.2
print(a , b , c)
# Out:
# python 1 12.2

# %%
# binary format ->  0 , 1 | True or flase | Yes or no

# True and False

# %%
False = choice
# Out:
#   File "/tmp/ipython-input-2043874759.py", line 1
#     False = choice
#     ^
# SyntaxError: cannot assign to False

# %%
#Multiple assignment variable
age,city=21,'Indore'
print(age,city)
# Out:
# 21 Indore

# %%
age = fav = 7  # you can assign the same value to multiple python variables.
print(age,fav)
# Out:
# 7 7

# %%
a,b='red','blue'
a,b=b,a         #swapping variable
print(a,b)
# Out:
# blue red

# %%
a='red'

del a
a
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-452567946.py in <cell line: 0>()
#       2
#       3 del a
# ----> 4 a
#
# NameError: name 'a' is not defined

# %%
car="BMW"
Car="Mercedes"
CAR="Jaguar"
print(car)
print(Car)
print(CAR)
# Out:
# BMW
# Mercedes
# Jaguar
